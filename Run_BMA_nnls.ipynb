# %%
import Script_BMA_Unmixing_nnls
import importlib
importlib.reload(Script_BMA_Unmixing_nnls)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_BMA_Unmixing_nnls.BMA(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
unmixing_instance.selectedindex_fit(mineral_type = 2, region = 1, MaxVars=3)
# Out:
# ['montmorillonite hill 1']
# BMA-Top 8 most common minerals and their associated most common abundances:
#                                      Name        Category                              Formula  Probability  Abundance
# 0               azurite.spc Azurite WS316       Carbonate                       Cu3(CO3)2(OH)2     0.379334   0.364765
# 1  hyperst4.spc Hypersthene PYX02.b 120um     Inosilicate                      (Mg,Fe+2)2Si2O6     0.168692   0.126952
# 2  hyperst2.spc Hypersthene PYX02.h >250u     Inosilicate                      (Mg,Fe+2)2Si2O6     0.115374   0.151493
# 3   hyperst5.spc Hypersthene PYX02.f 60um     Inosilicate                      (Mg,Fe+2)2Si2O6     0.173799   0.117906
# 4   mascagn1.spc Mascagnite GDS65.a (crs)         Sulfate                            (NH4)2SO4     0.098841   0.287376
# 5  hyperst3.spc Hypersthene PYX02.c 180um     Inosilicate                      (Mg,Fe+2)2Si2O6     0.152145   0.135278
# 6        glauconi.spc Glauconite HS313.3B  Phyllosilicate  (K,Na)(Fe+3,Al,Mg)2(Si,Al)4O10(OH)2     0.672361   0.389966
# 7            bronzite.spc Bronzite HS9.3B     Inosilicate                      (Mg,Fe+2)2Si2O6     0.187430   0.142349
# Run time: 177.42395615577698 seconds
