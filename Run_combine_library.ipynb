# %%
import Script_combine_library
import importlib
importlib.reload(Script_combine_library)

spectral_library_filename = "usgs_minerals.hdr"
spectral_library_filename2 = "UPWINS_4_16_2024.hdr"

import_instance1 = Script_combine_library.Import_lib(spectral_library_filename)
import_instance2 = Script_combine_library.Import_lib(spectral_library_filename2)
# Out:
# n_bands: 50
# n_spectra: 481
# spectral_library: [[0.50629944 0.46576953 0.4457388  ... 0.4708811  0.45864886 0.44131064]
#  [0.04290241 0.03216713 0.02346629 ... 0.09246773 0.09699623 0.10161966]
#  [0.39322925 0.38282418 0.37766442 ... 0.27684546 0.27034107 0.26564056]
#  ...
#  [0.30812207 0.30833495 0.3108517  ... 0.32680926 0.3269047  0.32685727]
#  [0.7647456  0.76248986 0.76356506 ... 0.75682133 0.75571436 0.7541236 ]
#  [0.70798075 0.7122183  0.7170167  ... 0.37258115 0.35532162 0.3818687 ]]
# n_bands: 2151
# n_spectra: 938
# spectral_library: [[ 0.09263058  0.08961927  0.08292663 ...  0.06007494  0.06004615
#    0.0597952 ]
#  [ 0.06966443  0.06767572  0.06070522 ...  0.04030095  0.04070007
#    0.03969653]
#  [ 0.08245274  0.08231796  0.07564572 ...  0.06157764  0.06138739
#    0.0617337 ]
#  ...
#  [ 0.01501113  0.01223278  0.01650478 ...  0.05245096  0.05234722
#    0.05272223]
#  [ 0.01129462  0.01394754  0.00866296 ...  0.06786097  0.06715313
#    0.06661396]
# ...

# %%
spectral_library_filenames = [spectral_library_filename, spectral_library_filename2]
combine_instance1 = Script_combine_library.combine(spectral_library_filenames)
# Out:
# Library 1:
#   n_bands: 50
#   n_spectra: 481
# Library 2:
#   n_bands: 2151
#   n_spectra: 938
