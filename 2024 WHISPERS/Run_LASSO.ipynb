# %%
import Script_LASSO_Unmixing
import importlib
importlib.reload(Script_LASSO_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROI6s.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_LASSO_Unmixing.LASSO(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)
# Out:
# c:\Users\stvp2\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Select mineral type 1 through 4
unmixing_instance.selectedindex_fit(mineral_type = 2, region = 1)
# Out:
# ['montmorillonite hill 1']
# Percent Accracy: 0%
# LASSO Regression-Top 5 most common minerals and their associated most common abundances:
#                                  Name        Category                      Formula  Abundance
# 0          analcime.spc Analcime GDS1   Tectosilicate                NaAlSi2O6*H2O   0.404448
# 1  lepidol5.spc Lepidolite NMNH105541  Phyllosilicate  K(Li,Al)3(Si,Al)4O10(F,OH)2   0.101843
# 2  neodymiu.spc Neodymium_Oxide GDS34           Oxide                        Nd2O3   0.088484
# 3   carnall1.spc Carnallite NMNH98011          Halide                  KMgCl3*6H2O   0.030334
# 4        laumonti.spc Laumontite GDS5   Tectosilicate             CaAl2Si4O12*4H2O   0.044855
# Run time: 1.485701322555542 seconds
