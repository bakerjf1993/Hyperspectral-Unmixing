# %%
import Script_OLS_Unmixing
import importlib
importlib.reload(Script_OLS_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_OLS_Unmixing.OLS(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.selectedindex_fit(mineral_type = 1, region = 1)
# Out:
# ['alunite hill 1']
# OLS Regression-Top 481 most common minerals and their associated most common abundances:
#                                        Name  \
# 0    a-alunit.spc Ammonioalunite NMNH145596
# 1      a-chlori.spc Ammonium_Chloride GDS77
# 2    a-illite.spc Ammonio-Illite/Smec GDS87
# 3     a-jarosi.spc Ammonio-jarosite SCR-NHJ
# 4       a-smecti.spc Ammonio-Smectite GDS86
# ..                                      ...
# 476         witherit.spc Witherite HS273.3B
# 477      wollasto.spc Wollastonite HS348.3B
# 478   zincite.spc Zincite+Franklin HS147.3B
# 479                 zircon.spc Zircon WS522
# 480            zoisite.spc Zoisite HS347.3B
#
#                                               Category  \
# 0                                              Sulfate
# 1                                               Halide
# 2                                       Phyllosilicate
# 3                                              Sulfate
# 4                                       Phyllosilicate
# ..                                                 ...
# 476                                          Carbonate
# 477                                        Inosilicate
# 478  Oxide mineral (Zincite) + Oxide mineral (Frank...
# 479                                       Nesosilicate
# 480                                       Nesosilicate
#
#                                                Formula  Abundance
# 0                                  (NH4)Al3(SO4)2(OH)6  -0.201853
# 1                                                NH4Cl   0.045636
# 2    NH4Al2(Si3Al)O10(OH)2 + (NH4)0.33(Al,Mg)2Si4O1...   0.000498
# 3                              (NH4)(Fe+3)3(SO4)2(OH)6  -0.043052
# 4                    (NH4)0.33(Al,Mg)2Si4O10(OH)2*nH2O   0.181178
# ..                                                 ...        ...
# 476                                              BaCO3  -0.074501
# 477                                             CaSiO3  -0.196724
# 478                                             ZrSiO4   0.064759
# 479                                             ZrSiO4  -0.014415
# 480                                  Ca2Al3(SiO4)3(OH)  -0.033603
#
# [481 rows x 4 columns]
# Run time: 3.2716784477233887 seconds
