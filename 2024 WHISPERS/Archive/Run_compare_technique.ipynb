# %%
import Script_Compare_Technique
import importlib
importlib.reload(Script_Compare_Technique)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
spectral_library_filename = "usgs_minerals.hdr"

# %%
unmixing_compare = Script_Compare_Technique.COMPARE(image_hdr_filename, image_filename, spectral_library_filename)
unmixing_compare.run_techniques_multiple_times(mineral_type = 2,region = 1)
# Out:
# ['montmorillonite hill 1']
# OLS Regression-Top 481 most common minerals and their associated most common abundances:
#                                         Name                                           Category                                            Formula  Abundance
# 0     a-alunit.spc Ammonioalunite NMNH145596                                            Sulfate                                (NH4)Al3(SO4)2(OH)6  -0.130371
# 1       a-chlori.spc Ammonium_Chloride GDS77                                             Halide                                              NH4Cl   0.003239
# 2     a-illite.spc Ammonio-Illite/Smec GDS87                                     Phyllosilicate  NH4Al2(Si3Al)O10(OH)2 + (NH4)0.33(Al,Mg)2Si4O1...  -0.026343
# 3      a-jarosi.spc Ammonio-jarosite SCR-NHJ                                            Sulfate                            (NH4)(Fe+3)3(SO4)2(OH)6  -0.087007
# ...
