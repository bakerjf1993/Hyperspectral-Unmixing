# %%
import Script_NNLS_Unmixing
import importlib
importlib.reload(Script_NNLS_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_NNLS_Unmixing.NNLS(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# NNLS Regression-Top 9 most common minerals and their associated most common abundances:
#                                      Name        Category                              Formula  Abundance
# 0               azurite.spc Azurite WS316       Carbonate                       Cu3(CO3)2(OH)2   0.450756
# 1  halloys5.spc Halloysite+Kaolinite CM29  Phyllosilicate  mixture of halloysite and kaolinite   0.495922
# 2        carnall2.spc Carnallite HS430.3B          Halide                          KMgCl3*6H2O   0.199485
# 3   mascagn1.spc Mascagnite GDS65.a (crs)         Sulfate                            (NH4)2SO4   1.303978
# 4    a-chlori.spc Ammonium_Chloride GDS77          Halide                                NH4Cl   1.160357
# 5              kaolini1.spc Kaolinite CM9  Phyllosilicate                        Al2Si2O5(OH)4   0.417683
# 6  elbaite1.spc Elbaite NMNH94217-1.a 659   Cyclosilicate       Na(Li,Al)3Al6(BO3)3Si6O18(OH)4   0.056575
# 7         dickite1.spc Dickite NMNH106242  Phyllosilicate                        Al2Si2O5(OH)4   0.119219
# 8           alunite5.spc Alunite HS295.3B         Sulfate                 (Na,K)Al3(SO4)2(OH)6   0.163846
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Run time: 1.297983169555664 seconds
