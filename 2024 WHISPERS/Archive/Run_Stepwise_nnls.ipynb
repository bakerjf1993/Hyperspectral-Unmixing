# %%
import Script_Stepwise_Unmixing
import importlib
importlib.reload(Script_Stepwise_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_Stepwise_Unmixing.STEPWISE(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.forward_selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# Forward Stepwise Regression-Top 2 most common minerals and their associated most common abundances:
#                                   Name        Category        Formula  Abundance
# 0  kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate  Al2Si2O5(OH)4   0.595877
# 1       dickite2.spc Dickite NMNH46967  Phyllosilicate  Al2Si2O5(OH)4   0.708195
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Run time: 175.2168002128601 seconds

# %%
unmixing_instance.backward_selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# Backward Stepwise Regression-Top 3 most common minerals and their associated most common abundances:
#                                      Name        Category                         Formula  Abundance
# 0              kaolini8.spc Kaolinite CM7  Phyllosilicate                   Al2Si2O5(OH)4   0.901632
# 1           tremoli1.spc Tremolite HS18.3     Inosilicate               Ca2Mg5Si8O22(OH)2   0.130015
# 2  elbaite2.spc Elbaite NMNH94217-1.b 196   Cyclosilicate  Na(Li,Al)3Al6(BO3)3Si6O18(OH)4   0.397673
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Run time: 148.49425315856934 seconds
