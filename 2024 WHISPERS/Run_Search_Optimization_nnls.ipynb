# %%
import Script_Search_Optimization_Unmixing
import importlib
importlib.reload(Script_Search_Optimization_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_Search_Optimization_Unmixing.Search_Optimization(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)
unmixing_instance.depth_first_selectedindex_fit(mineral_type = 2, region = 1)
unmixing_instance.breadth_first_selectedindex_fit(mineral_type = 2, region = 1)
# Out:
# ['kaolinite region 1']
# Number of pixel samples analyzed: 120
# Number of models including the target mineral: 94
# Proportion of models including the target mineral: 0.7833
# ['kaolinite region 1']
# Number of pixel samples analyzed: 120
# Number of models including the target mineral: 94
# Proportion of models including the target mineral: 0.7833
