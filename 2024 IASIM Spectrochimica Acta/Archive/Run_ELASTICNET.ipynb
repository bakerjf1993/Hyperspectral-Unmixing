# %%
import Script_ELASTICNET_Unmixing
import importlib
importlib.reload(Script_ELASTICNET_Unmixing)
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})
plt.rc('legend',fontsize=10)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_ELASTICNET_Unmixing.ELASTICNET(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# Percent Accracy: 100%
# ElasticNet-Top 13 most common minerals and their associated most common abundances:
#                                       Name        Category                              Formula  Abundance
# 0               kaolini6.spc Kaolinite CM3  Phyllosilicate                        Al2Si2O5(OH)4   0.108714
# 1      kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate                        Al2Si2O5(OH)4   0.104554
# 2               kaolini7.spc Kaolinite CM5  Phyllosilicate                        Al2Si2O5(OH)4   0.104050
# 3   elbaite2.spc Elbaite NMNH94217-1.b 196   Cyclosilicate       Na(Li,Al)3Al6(BO3)3Si6O18(OH)4   0.075865
# 4   elbaite1.spc Elbaite NMNH94217-1.a 659   Cyclosilicate       Na(Li,Al)3Al6(BO3)3Si6O18(OH)4   0.059704
# 5          dickite1.spc Dickite NMNH106242  Phyllosilicate                        Al2Si2O5(OH)4   0.169649
# ...
