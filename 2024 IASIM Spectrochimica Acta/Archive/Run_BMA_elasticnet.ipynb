# %%
import Script_BMA_Unmixing_elasticnet
import importlib
importlib.reload(Script_BMA_Unmixing_elasticnet)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_BMA_Unmixing_elasticnet.BMA_elasticnet(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
unmixing_instance.selectedindex_fit(mineral_type = 3, region = 1, MaxVars=2)
# Out:
# ['kaolinite region 1']
# Percent Accracy: 64%
# BMA_elasticnet-Top 3 most common minerals and their associated most common abundances:
#                                     Name        Category                   Formula  Probability  Abundance
# 0              azurite.spc Azurite WS316       Carbonate            Cu3(CO3)2(OH)2     0.580317   0.346320
# 1  epidote1.spc Epidote GDS26.a 75-200um    Sorosilicate  Ca2(Al,Fe+3)3(SiO4)3(OH)     0.626552   0.110653
# 2    kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate             Al2Si2O5(OH)4     0.696850   0.532764
# Run time: 79.77829027175903 seconds
