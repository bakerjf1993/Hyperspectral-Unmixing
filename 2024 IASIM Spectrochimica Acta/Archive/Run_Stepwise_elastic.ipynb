# %%
import Script_Stepwise_ELASTIC_Unmixing
import importlib
importlib.reload(Script_Stepwise_ELASTIC_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_Stepwise_ELASTIC_Unmixing.STEPWISE(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.forward_selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# Percent Accracy: 78%
# Forward Stepwise - Elasticnet Regression-Top 2 most common minerals and their associated most common abundances:
#                                   Name        Category        Formula  Abundance
# 0       dickite2.spc Dickite NMNH46967  Phyllosilicate  Al2Si2O5(OH)4   0.595405
# 1  kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate  Al2Si2O5(OH)4   0.639056
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Run time: 169.8197796344757 seconds
