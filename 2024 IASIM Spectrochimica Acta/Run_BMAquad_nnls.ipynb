# %%
import Script_BMAquad_Unmixing_nnls
import importlib
importlib.reload(Script_BMAquad_Unmixing_nnls)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_BMAquad_Unmixing_nnls.BMAquad_nnls(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
unmixing_instance.selectedindex_fit(mineral_type = 1, region = 1, MaxVars=2)
# Out:
# ['alunite hill 1']
# Percent Accracy: 81%
# BMA with Linear and Quadratic Terms-NNLS-Top 3 most common minerals and their associated most common abundances:
#                                      Name        Category                                            Formula  Probability  Abundance
# 0         alunite1.spc Alunite GDS84 Na03         Sulfate                               (Na,K)Al3(SO4)2(OH)6     0.821451   0.241496
# 1           alunite4.spc Alunite AL706 Na         Sulfate                               (Na,K)Al3(SO4)2(OH)6     0.871725   0.300016
# 2  a-illite.spc Ammonio-Illite/Smec GDS87  Phyllosilicate  NH4Al2(Si3Al)O10(OH)2 + (NH4)0.33(Al,Mg)2Si4O1...     0.960195   0.767729
# Run time: 10.000332593917847 seconds
