# %%
import Script_Search_Optimization_NNLS_Unmixing
import importlib
importlib.reload(Script_Search_Optimization_NNLS_Unmixing)

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})
plt.rc('legend',fontsize=10)

import warnings
from sklearn.exceptions import ConvergenceWarning

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_Search_Optimization_NNLS_Unmixing.Search_Optimization_nnls(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.depth_first_selectedindex_fit(mineral_type = 3, region = 1)
unmixing_instance.breadth_first_selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# Number of pixel samples analyzed: 120
# Average unmixing computation time: 2.3876098374525707
# Average RMSE: 0.041175994342718424
# Number of models including the target mineral: 94
# Proportion of models including the target mineral: 0.7833
# Minerals Contributing to Inferred Spectrum:
#                                Mineral       Category                             Formula  Abundance
#  mascagn1.spc Mascagnite GDS65.a (crs)        Sulfate                           (NH4)2SO4     2.2882
# halloys5.spc Halloysite+Kaolinite CM29 Phyllosilicate mixture of halloysite and kaolinite     0.5863
# hyperst2.spc Hypersthene PYX02.h >250u    Inosilicate                     (Mg,Fe+2)2Si2O6     0.4501
#              azurite.spc Azurite WS316      Carbonate                      Cu3(CO3)2(OH)2     0.4101
#             kaolini1.spc Kaolinite CM9 Phyllosilicate                       Al2Si2O5(OH)4     0.3504
#       carnall2.spc Carnallite HS430.3B         Halide                         KMgCl3*6H2O     0.2329
# elbaite1.spc Elbaite NMNH94217-1.a 659  Cyclosilicate      Na(Li,Al)3Al6(BO3)3Si6O18(OH)4     0.0882
#          alunite5.spc Alunite HS295.3B        Sulfate                (Na,K)Al3(SO4)2(OH)6     0.0086
#       pyrophy3.spc Pyrophyllite SU1421 Phyllosilicate                      Al2Si4O10(OH)2     0.0043
# Depth First Search-Top 2 most common minerals and their associated most common abundances:
#                                   Name        Category        Formula  Abundance
# 0  kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate  Al2Si2O5(OH)4   0.595877
# 1       dickite2.spc Dickite NMNH46967  Phyllosilicate  Al2Si2O5(OH)4   0.708195
# ['kaolinite region 1']
# Number of pixel samples analyzed: 120
# Average unmixing computation time: 4.2950823426246645
# Average RMSE: 0.04824562700703279
# Number of models including the target mineral: 53
# Proportion of models including the target mineral: 0.4417
# Minerals Contributing to Inferred Spectrum:
#                                Mineral       Category                             Formula  Abundance
#  mascagn1.spc Mascagnite GDS65.a (crs)        Sulfate                           (NH4)2SO4     1.4625
#              azurite.spc Azurite WS316      Carbonate                      Cu3(CO3)2(OH)2     0.5757
#  c-black.spc Carbon_Black GDS68 sm.ap.         Carbon                                   C     0.4725
#             kaolini1.spc Kaolinite CM9 Phyllosilicate                       Al2Si2O5(OH)4     0.4602
#             kaolini7.spc Kaolinite CM5 Phyllosilicate                       Al2Si2O5(OH)4     0.3819
#       carnall2.spc Carnallite HS430.3B         Halide                         KMgCl3*6H2O     0.1195
# hyperst4.spc Hypersthene PYX02.b 120um    Inosilicate                     (Mg,Fe+2)2Si2O6     0.0696
# halloys5.spc Halloysite+Kaolinite CM29 Phyllosilicate mixture of halloysite and kaolinite     0.0576
# elbaite1.spc Elbaite NMNH94217-1.a 659  Cyclosilicate      Na(Li,Al)3Al6(BO3)3Si6O18(OH)4     0.0392
# Breadth First Search-Top 4 most common minerals and their associated most common abundances:
#                                      Name        Category                         Formula  Abundance
# 0              kaolini8.spc Kaolinite CM7  Phyllosilicate                   Al2Si2O5(OH)4   0.893804
# 1  elbaite2.spc Elbaite NMNH94217-1.b 196   Cyclosilicate  Na(Li,Al)3Al6(BO3)3Si6O18(OH)4   0.392103
# 2           tremoli1.spc Tremolite HS18.3     Inosilicate               Ca2Mg5Si8O22(OH)2   0.129997
# 3           epidote3.spc Epidote HS328.3B    Sorosilicate        Ca2(Al,Fe+3)3(SiO4)3(OH)   0.144491
