# %%
import Script_Search_Optimization_elasticnet_Unmixing
import importlib
importlib.reload(Script_Search_Optimization_elasticnet_Unmixing)

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})
plt.rc('legend',fontsize=10)

import warnings
from sklearn.exceptions import ConvergenceWarning

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_Search_Optimization_elasticnet_Unmixing.Search_Optimization_elasticnet(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.depth_first_selectedindex_fit(mineral_type = 3, region = 1)
unmixing_instance.breadth_first_selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# Number of pixel samples analyzed: 120
# Average unmixing computation time: 2.628531430164973
# Average RMSE: 0.0732760031135437
# Number of models including the target mineral: 95
# Proportion of models including the target mineral: 0.7917
# Minerals Contributing to Inferred Spectrum:
#                           Mineral     Category Formula  Abundance
# silliman.spc Sillimanite HS186.3B Nesosilicate Al2SiO5        0.0
# Depth First Search-Top 2 most common minerals and their associated most common abundances:
#                                   Name        Category        Formula  Abundance
# 0       dickite2.spc Dickite NMNH46967  Phyllosilicate  Al2Si2O5(OH)4   0.595405
# 1  kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate  Al2Si2O5(OH)4   0.639056
# ['kaolinite region 1']
# Number of pixel samples analyzed: 120
# Average unmixing computation time: 4.6093780616919195
# Average RMSE: 0.1497622004239509
# Number of models including the target mineral: 54
# ...
