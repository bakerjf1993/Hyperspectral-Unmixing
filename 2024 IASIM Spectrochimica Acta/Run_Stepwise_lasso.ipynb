# %%
import Script_Stepwise_Lasso_Unmixing
import importlib
importlib.reload(Script_Stepwise_Lasso_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_Stepwise_Lasso_Unmixing.STEPWISE(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.forward_selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# c:\Users\stvp2\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.590e-04, tolerance: 8.250e-05
#   model = cd_fast.enet_coordinate_descent(
# Percent Accracy: 74%
# Forward Stepwise - Lasso Regression-Top 2 most common minerals and their associated most common abundances:
#                                   Name        Category        Formula  Abundance
# 0  kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate  Al2Si2O5(OH)4   0.676093
# 1       dickite2.spc Dickite NMNH46967  Phyllosilicate  Al2Si2O5(OH)4   0.616220
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Run time: 167.44904565811157 seconds
