# %%
import Script_Search_Optimization_Lasso_Unmixing
import importlib
importlib.reload(Script_Search_Optimization_Lasso_Unmixing)

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})
plt.rc('legend',fontsize=10)

import warnings
from sklearn.exceptions import ConvergenceWarning

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_Search_Optimization_Lasso_Unmixing.Search_Optimization_lasso(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.depth_first_selectedindex_fit(mineral_type = 3, region = 1)
unmixing_instance.breadth_first_selectedindex_fit(mineral_type = 3, region = 1)
# Out:
# ['kaolinite region 1']
# c:\Users\stvp2\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.590e-04, tolerance: 8.250e-05
#   model = cd_fast.enet_coordinate_descent(
# Number of pixel samples analyzed: 120
# Average unmixing computation time: 3.4025154332319896
# Average RMSE: 0.07323795713384294
# Number of models including the target mineral: 91
# Proportion of models including the target mineral: 0.7583
# Minerals Contributing to Inferred Spectrum:
#                                Mineral       Category                        Formula  Abundance
#            gibbsit2.spc Gibbsite WS214      Hydroxide                        Al(OH)3     0.2570
#        dickite1.spc Dickite NMNH106242 Phyllosilicate                  Al2Si2O5(OH)4     0.2103
#  epidote1.spc Epidote GDS26.a 75-200um   Sorosilicate       Ca2(Al,Fe+3)3(SiO4)3(OH)     0.1130
#             kaolini6.spc Kaolinite CM3 Phyllosilicate                  Al2Si2O5(OH)4     0.1117
#    kaolini2.spc Kaolinite KGa-1 (wxyl) Phyllosilicate                  Al2Si2O5(OH)4     0.0993
#   mascagn2.spc Mascagnite GDS65.b (fn)        Sulfate                      (NH4)2SO4     0.0465
# elbaite2.spc Elbaite NMNH94217-1.b 196  Cyclosilicate Na(Li,Al)3Al6(BO3)3Si6O18(OH)4     0.0224
#     strontia.spc Strontianite HS272.3B      Carbonate                          SrCO3     0.0044
# Depth First Search-Top 2 most common minerals and their associated most common abundances:
#                                   Name        Category        Formula  Abundance
# 0  kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate  Al2Si2O5(OH)4   0.676093
# 1       dickite2.spc Dickite NMNH46967  Phyllosilicate  Al2Si2O5(OH)4   0.616220
# ['kaolinite region 1']
