# %%
import Script_NNLS_Unmixing
import importlib
importlib.reload(Script_NNLS_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_NNLS_Unmixing.NNLS(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.selectedindex_fit(mineral_type = 1, region = 1)
# Out:
# ['alunite hill 1']
# NNLS Regression-Top 9 most common minerals and their associated most common abundances:
#                                      Name        Category               Formula  Abundance
# 0           alunite5.spc Alunite HS295.3B         Sulfate  (Na,K)Al3(SO4)2(OH)6   1.033390
# 1    a-chlori.spc Ammonium_Chloride GDS77          Halide                 NH4Cl   0.882530
# 2         natroli1.spc Natrolite HS169.3B  Phyllosilicate     Na2Al2Si3O10*2H20   0.118551
# 3    mascagn2.spc Mascagnite GDS65.b (fn)         Sulfate             (NH4)2SO4   0.214839
# 4    ulexite2.spc Ulexite GDS138 Boron CA          Borate         NaCaB5O9*8H2O   1.611786
# 5          h2o-ice.spc H2O-Ice GDS136 77K   Mineral (ice)                   H2O   0.172826
# 6  hyperst2.spc Hypersthene PYX02.h >250u     Inosilicate       (Mg,Fe+2)2Si2O6   0.510238
# 7   scolecit.spc Scolecite GDS7 acid trtd   Tectosilicate      CaAl2Si3O10*3H2O   0.125610
# ...
