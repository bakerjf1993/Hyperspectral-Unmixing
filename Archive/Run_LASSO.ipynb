# %%
import Script_LASSO_Unmixing
import importlib
importlib.reload(Script_LASSO_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_LASSO_Unmixing.LASSO(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.selectedindex_fit(mineral_type = 1, region = 2)
# Out:
# ['alunite hill 2']
# LASSO Regression-Top 3 most common minerals and their associated most common abundances:
#                                      Name Category               Formula  Abundance
# 0         alunite1.spc Alunite GDS84 Na03  Sulfate  (Na,K)Al3(SO4)2(OH)6   0.397104
# 1  a-alunit.spc Ammonioalunite NMNH145596  Sulfate   (NH4)Al3(SO4)2(OH)6   0.240114
# 2    mascagn2.spc Mascagnite GDS65.b (fn)  Sulfate             (NH4)2SO4   0.148162
# Run time: 1.4837799072265625 seconds
