# %%
import Script_Stepwise_Unmixing
import importlib
importlib.reload(Script_Stepwise_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_Stepwise_Unmixing.STEPWISE(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.forward_selectedindex_fit(mineral_type = 1, region = 1)
# Out:
# ['alunite hill 1']
# Forward Stepwise Regression-Top 2 most common minerals and their associated most common abundances:
#                                    Name Category               Formula  Abundance
# 0       alunite1.spc Alunite GDS84 Na03  Sulfate  (Na,K)Al3(SO4)2(OH)6   0.926120
# 1  a-chlori.spc Ammonium_Chloride GDS77   Halide                 NH4Cl   0.999806
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Run time: 207.71864819526672 seconds

# %%
unmixing_instance.backward_selectedindex_fit(mineral_type = 1, region = 1)
# Out:
# ['alunite hill 1']
# Backward Stepwise Regression-Top 3 most common minerals and their associated most common abundances:
#                                      Name        Category              Formula  Abundance
# 0              howlite.spc Howlite GDS155          Borate       Ca2B5SiO9(OH)5   0.264493
# 1  a-alunit.spc Ammonioalunite NMNH145596         Sulfate  (NH4)Al3(SO4)2(OH)6   0.621111
# 2              kaolini8.spc Kaolinite CM7  Phyllosilicate        Al2Si2O5(OH)4   0.353094
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Run time: 205.18290972709656 seconds
