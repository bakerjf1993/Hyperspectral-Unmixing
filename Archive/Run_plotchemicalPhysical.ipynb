# %%
import Script_plotchemicalPhysical
import importlib
importlib.reload(Script_plotchemicalPhysical)
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})
plt.rc('legend',fontsize=10)

spectral_library_filename = "usgs_minerals.hdr"

# %%
plot_chemicalPhysical = Script_plotchemicalPhysical.chemphys( spectral_library_filename)
