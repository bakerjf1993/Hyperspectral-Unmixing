# %%
import Script_BMAquad_Unmixing_nnls
import importlib
importlib.reload(Script_BMAquad_Unmixing_nnls)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_BMAquad_Unmixing_nnls.BMAquad(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
unmixing_instance.selectedindex_fit(mineral_type = 3, region = 1, MaxVars=2)
# Out:
# ['kaolinite region 1']
# BMA with Linear and Quadratic Terms-Top 4 most common minerals and their associated most common abundances:
#                                   Name        Category        Formula  Probability  Abundance
# 0           kaolini6.spc Kaolinite CM3  Phyllosilicate  Al2Si2O5(OH)4     0.376925   0.117954
# 1  kaolini2.spc Kaolinite KGa-1 (wxyl)  Phyllosilicate  Al2Si2O5(OH)4     0.276408   0.092196
# 2       dickite2.spc Dickite NMNH46967  Phyllosilicate  Al2Si2O5(OH)4     0.622831   0.244272
# 3           kaolini7.spc Kaolinite CM5  Phyllosilicate  Al2Si2O5(OH)4     0.199130   0.065939
# Run time: 39.46701526641846 seconds
