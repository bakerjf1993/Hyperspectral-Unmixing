# %%
import Script_RIDGE_Unmixing
import importlib
importlib.reload(Script_RIDGE_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_RIDGE_Unmixing.RIDGE(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
unmixing_instance.selectedindex_fit(mineral_type = 2, region = 1)
# Out:
# ['montmorillonite hill 1']
# RIDGE Regression-Top 158 most common minerals and their associated most common abundances:
#                                        Name                          Category                                            Formula  Abundance
# 0      a-chlori.spc Ammonium_Chloride GDS77                            Halide                                              NH4Cl   0.013179
# 1              acmite.spc Acmite NMNH133746                       Inosilicate                                          NaFeSi2O6   0.018183
# 2            allanite.spc Allanite HS293.3B                      Sorosilicate                    (Ce,Ca,Y)2(Al,Fe3+)3(SiO4)3(OH)   0.002093
# 3        andalusi.spc Andalusite NMNHR17898                      Nesosilicate                                            Al2SiO5   0.005465
# 4              andradi5.spc Andradite WS488                      Nesosilicate                                  Ca3(Fe+3)2(SiO4)3   0.008206
# ..                                      ...                               ...                                                ...        ...
# 153    desertv3.spc Desert_Varnish ANP90-14  Coating on rocks (not a mineral)  mixtures of manganese and iron oxides, &clay m...   0.001902
# 154  nontron3.spc Nontronite NG-1.b <2um fr                    Phyllosilicate                      Na0.33(Fe+3)2(Si,Al)4O10*nH20   0.003172
# 155      riebeck1.spc Riebeckite NMNH122689                       Inosilicate                       Na2Fe(+2)3Fe(+3)2Si8O22(OH)2   0.002936
# 156  chlorit3.spc Chlorite SMR-13.b 60-104u                    Phyllosilicate             (Mg,Fe)3(Si,Al)4O10(OH)2-(Mg,Fe)3(OH)6   0.006736
# 157  chlorit4.spc Chlorite SMR-13.c 45-60um                    Phyllosilicate             (Mg,Fe)3(Si,Al)4O10(OH)2-(Mg,Fe)3(OH)6   0.005442
#
# [158 rows x 4 columns]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Run time: 1.7054100036621094 seconds
