# %%
import Script_OLS_Unmixing
import importlib
importlib.reload(Script_OLS_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
pixel_location = "ROIs2.csv"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_OLS_Unmixing.OLS(image_hdr_filename, image_filename, pixel_location, spectral_library_filename)

# %%
# Select mineral type 1 through 4
unmixing_instance.selectedindex_fit(mineral_type = 1, region = 1)
# Out:
# ['alunite hill 1']
# OLS Regression-Top 481 most common minerals and their associated most common abundances:
#                                        Name                                           Category                                            Formula  Abundance
# 0    a-alunit.spc Ammonioalunite NMNH145596                                            Sulfate                                (NH4)Al3(SO4)2(OH)6  -0.201465
# 1      a-chlori.spc Ammonium_Chloride GDS77                                             Halide                                              NH4Cl   0.045788
# 2    a-illite.spc Ammonio-Illite/Smec GDS87                                     Phyllosilicate  NH4Al2(Si3Al)O10(OH)2 + (NH4)0.33(Al,Mg)2Si4O1...   0.000421
# 3     a-jarosi.spc Ammonio-jarosite SCR-NHJ                                            Sulfate                            (NH4)(Fe+3)3(SO4)2(OH)6  -0.043122
# 4       a-smecti.spc Ammonio-Smectite GDS86                                     Phyllosilicate                  (NH4)0.33(Al,Mg)2Si4O10(OH)2*nH2O   0.181115
# ..                                      ...                                                ...                                                ...        ...
# 476         witherit.spc Witherite HS273.3B                                          Carbonate                                              BaCO3  -0.074517
# 477      wollasto.spc Wollastonite HS348.3B                                        Inosilicate                                             CaSiO3  -0.196704
# 478   zincite.spc Zincite+Franklin HS147.3B  Oxide mineral (Zincite) + Oxide mineral (Frank...                                             ZrSiO4   0.064775
# 479                 zircon.spc Zircon WS522                                       Nesosilicate                                             ZrSiO4  -0.014410
# 480            zoisite.spc Zoisite HS347.3B                                       Nesosilicate                                  Ca2Al3(SiO4)3(OH)  -0.033573
#
# [481 rows x 4 columns]
# Run time: 3.896047353744507 seconds
