# %%
import Script_NNLS_wideobs
import importlib
importlib.reload(Script_NNLS_wideobs)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_NNLS_wideobs.NNLS(image_hdr_filename, image_filename, spectral_library_filename)

# %%
unmixing_instance.selectedindex_fit(mineral_type = 2,pixel_radius=15)
# Out:
# Sample Centers
# 290 48
# Number of samples = (1+2r)^2 :961
# ...
