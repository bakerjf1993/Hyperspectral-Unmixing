# %%
import Script_NNLS_Unmixing
import importlib
importlib.reload(Script_NNLS_Unmixing)

image_hdr_filename = "cup95eff.hdr"
image_filename = "cup95eff.int"
spectral_library_filename = "usgs_minerals.hdr"

# Create an instance of the Unmix class
unmixing_instance = Script_NNLS_Unmixing.NNLS(image_hdr_filename, image_filename, spectral_library_filename)

# %%
mineral = 3
if mineral == 1:
    index_to_unmix = [305,90] #alunite
elif mineral == 2:
    index_to_unmix = [349,48] #montmorillonite
else:    
    index_to_unmix = [290,290] #kaolinite
unmixing_instance.selectedindex_fit(index_to_unmix,alpha=1)
unmixing_instance.plot_spectra()
unmixing_instance.final_summary()
# Out:
# Summary: NNLS Regression
# analcime.spc Analcime GDS1, Coefficient: 0.14165622057491356
# halloys5.spc Halloysite+Kaolinite CM29, Coefficient: 0.09628096597987366
# kaolini1.spc Kaolinite CM9, Coefficient: 0.09624700350502009
# alunite5.spc Alunite HS295.3B, Coefficient: 0.06604025014648744
# carnall1.spc Carnallite NMNH98011, Coefficient: 0.057059024542367574
# rhodoch1.spc Rhodochrosite HS338.3B, Coefficient: 0.04193834402820714
# jarosit1.spc Jarosite GDS99 K-y 200C, Coefficient: 0.02774477144427258
# pyrophy2.spc Pyrophyllite PYS1A <850um, Coefficient: 0.021674792587390735
# dolomit1.spc Dolomite HS102.3B, Coefficient: 0.013129539280395489
# dickite1.spc Dickite NMNH106242, Coefficient: 0.01115974589417227
# datolit1.spc Datolite HS442.3B, Coefficient: 0.00037665010404686343
# [('analcime.spc Analcime GDS1', 0.14165622057491356),
#  ('halloys5.spc Halloysite+Kaolinite CM29', 0.09628096597987366),
#  ('kaolini1.spc Kaolinite CM9', 0.09624700350502009),
#  ('alunite5.spc Alunite HS295.3B', 0.06604025014648744),
#  ('carnall1.spc Carnallite NMNH98011', 0.057059024542367574),
#  ('rhodoch1.spc Rhodochrosite HS338.3B', 0.04193834402820714),
#  ('jarosit1.spc Jarosite GDS99 K-y 200C', 0.02774477144427258),
#  ('pyrophy2.spc Pyrophyllite PYS1A <850um', 0.021674792587390735),
#  ('dolomit1.spc Dolomite HS102.3B', 0.013129539280395489),
#  ('dickite1.spc Dickite NMNH106242', 0.01115974589417227),
#  ('datolit1.spc Datolite HS442.3B', 0.00037665010404686343)]
